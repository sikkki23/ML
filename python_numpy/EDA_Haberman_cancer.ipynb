# %%
# %pip install kagglehub
# %pip install scipy
import kagglehub

# Download latest version
#path = kagglehub.dataset_download("gilsousa/habermans-survival-data-set")

#print("Path to dataset files:", path)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("haberman.csv")
df.head()
# Out:
#    Age  Operation_Year  Axilary_Lymph_Nodes  Survial_Status
# 0   30              64                    1               1
# 1   30              62                    3               1
# 2   30              65                    0               1
# 3   31              59                    2               1
# 4   31              65                    4               1

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['Age', 'Operation_Year', 'Axilary_Lymph_Nodes', 'Survial_Status'], dtype='object')
# (306, 4)

# %%
df["Survial_Status"] = df["Survial_Status"].map({1: "Yes", 2: "No"}).to_frame()
print(df.head())
print('-----------------------------------------------')
print(df.info())
# Out:
#    Age  Operation_Year  Axilary_Lymph_Nodes Survial_Status
# 0   30              64                    1            Yes
# 1   30              62                    3            Yes
# 2   30              65                    0            Yes
# 3   31              59                    2            Yes
# 4   31              65                    4            Yes
# -----------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  306 non-null    int64
#  1   Operation_Year       306 non-null    int64
#  2   Axilary_Lymph_Nodes  306 non-null    int64
#  3   Survial_Status       306 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 9.7+ KB
# None

# %%
print(df['Survial_Status'].value_counts())

print(df.columns)
# Out:
# Survial_Status
# Yes    225
# No      81
# Name: count, dtype: int64
# Index(['Age', 'Operation_Year', 'Axilary_Lymph_Nodes', 'Survial_Status'], dtype='object')

# %%
df.plot(kind='scatter', x='Age', y='Operation_Year',title='Age vs Operation_Year')
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(data=df, hue='Survial_Status', height=6).map(plt.scatter, 'Age', 'Operation_Year').add_legend()
plt.show()

# %%
df_Survial_Yes = df[df['Survial_Status'] == 'Yes'] 
df_Survial_No = df[df['Survial_Status'] == 'No'] 

plt.plot(df_Survial_Yes['Age'], np.zeros_like(df_Survial_Yes['Operation_Year']), 'o', label='Survial_Yes')
plt.plot(df_Survial_No['Age'], np.zeros_like(df_Survial_No['Operation_Year']), 'o', label='Survial_No')
plt.legend()

# %%
sns.FacetGrid(df, hue='Survial_Status', height=5 ) \
    .map(sns.displot,"Age") \
        .add_legend()
plt.show()
# Out:
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
df.describe()
# Out:
#               Age  Operation_Year  Axilary_Lymph_Nodes
# count  306.000000      306.000000           306.000000
# mean    52.457516       62.852941             4.026144
# std     10.803452        3.249405             7.189654
# min     30.000000       58.000000             0.000000
# 25%     44.000000       60.000000             0.000000
# 50%     52.000000       63.000000             1.000000
# 75%     60.750000       65.750000             4.000000
# max     83.000000       69.000000            52.000000

# %%
df_Survial_Yes.describe()
# Out:
#               Age  Operation_Year  Axilary_Lymph_Nodes
# count  225.000000      225.000000           225.000000
# mean    52.017778       62.862222             2.791111
# std     11.012154        3.222915             5.870318
# min     30.000000       58.000000             0.000000
# 25%     43.000000       60.000000             0.000000
# 50%     52.000000       63.000000             0.000000
# 75%     60.000000       66.000000             3.000000
# max     77.000000       69.000000            46.000000

# %%
df_Survial_No.describe()
# Out:
#              Age  Operation_Year  Axilary_Lymph_Nodes
# count  81.000000       81.000000            81.000000
# mean   53.679012       62.827160             7.456790
# std    10.167137        3.342118             9.185654
# min    34.000000       58.000000             0.000000
# 25%    46.000000       59.000000             1.000000
# 50%    53.000000       63.000000             4.000000
# 75%    61.000000       65.000000            11.000000
# max    83.000000       69.000000            52.000000

# %% [markdown]
# ### 1. Univariant Analysis - Histogram

# %%
sns.FacetGrid(df, hue='Survial_Status', height=5 ) \
    .map(sns.displot,"Age") \
        .add_legend()
plt.show()
# Out:
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df, hue='Operation_Year', height=5 ) \
    .map(sns.displot,"Age") \
        .add_legend()
plt.show()
# Out:
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df.columns

sns.FacetGrid(df, hue='Axilary_Lymph_Nodes', height=5 ) \
    .map(sns.displot,"Age") \
        .add_legend()
plt.show()
# Out:
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\sicky\AppData\Roaming\Python\Python313\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
counts, bin_edges = np.histogram(df['Age'], bins=10, density=True)
pdf = counts / sum(counts) # probability density function
cdf = np.cumsum(pdf)       # cumulative density function
plt.plot(bin_edges[:-1], pdf, label='pdf')
plt.plot(bin_edges[:-1], cdf, label='CDF')

counts2, bin_edges2 = np.histogram(df['Operation_Year'], bins=10, density=True)
pdf2 = counts2 / sum(counts2) # probability density function
cdf2 = np.cumsum(pdf2)       # cumulative density function
plt.plot(bin_edges2[:-1], pdf2, label='pdf2')
plt.plot(bin_edges2[:-1], cdf2, label='CDF2')

#print(df.columns)
counts3, bin_edges3 = np.histogram(df['Axilary_Lymph_Nodes'], bins=10, density=True)
pdf3 = counts3 / sum(counts3) # probability density function
cdf3 = np.cumsum(pdf3)       # cumulative density function
plt.plot(bin_edges3[:-1], pdf2, label='pdf3')
plt.plot(bin_edges3[:-1], cdf2, label='CDF3')

plt.legend()
plt.show()

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(x= "Survial_Status", y="Age", data=df)
plt.show()
sns.boxplot(x= "Survial_Status", y="Operation_Year", data=df)
plt.show()
sns.boxplot(x= "Survial_Status", y="Axilary_Lymph_Nodes", data=df)
plt.show()

# %% [markdown]
# ### Violin Plot

# %%
sns.violinplot(x= "Survial_Status", y="Age", data=df)
plt.show()
sns.violinplot(x= "Survial_Status", y="Operation_Year", data=df)
plt.show()
sns.violinplot(x= "Survial_Status", y="Axilary_Lymph_Nodes", data=df)
plt.show()

# %% [markdown]
# ### Pair Plot
# combination of two Datain pair

# %%
sns.set_style('whitegrid')
sns.pairplot(data=df, hue='Survial_Status', height=6).map(plt.scatter).add_legend()
plt.show()

# %% [markdown]
# ### Multivariante Analysis

# %%
print(df.columns)
sns.jointplot(x="Operation_Year" , y= "Age", data = df, kind ='kde')
plt.show()
# Out:
# Index(['Age', 'Operation_Year', 'Axilary_Lymph_Nodes', 'Survial_Status'], dtype='object')

# %% [markdown]
# ### Q-Q Plot

# %%
import scipy.stats as stats
import pylab 

measuremnts = np.random.normal(loc=20, scale=5, size=1000)
stats.probplot(measuremnts, dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# Limitation if dataset is low then it's harder to interpret Q-Q plot
# size = 10

# %%
measuremnts = np.random.normal(loc=20, scale=5, size=10)
stats.probplot(measuremnts, dist="norm", plot=pylab)
pylab.show()

# %% [markdown]
# ### BOX-COX Transformation

# %%
#import scipy.stats as stats
#import matplotlib.pyplot as plt 

fig = plt.figure()
ax1 = fig.add_subplot(211)
x = stats.loggamma.rvs(5, size=1000) + 5
prob = stats.probplot(x, dist=stats.norm, plot=ax1)

ax1.set_xlabel('')
ax1.set_title('ProbPlot against normal distribution')

ax2= fig.add_subplot(212)
xt , _ = stats.boxcox(x)
prob = stats.probplot(xt, dist=stats.norm, plot=ax2)
ax2.set_title('probplot against normal distribution after Box-Cox transformation')
plt.show()
